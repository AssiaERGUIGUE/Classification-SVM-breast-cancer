# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/Admin/Downloads/data_breast_cancer.csv")
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
data=data.drop(["id","Unnamed: 32"],axis=1)

# %%
data.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
data.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
data.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
fig, axs = plt.subplots(3, 5, figsize=(15, 10))
fig.subplots_adjust(hspace=0.5, wspace=0.5)
axs = axs.ravel()

for i, column in enumerate(data.columns[2:]):
    axs[i].hist(data[data['diagnosis']=='M'][column], bins=30, alpha=0.5, color='red', label='M')
    axs[i].hist(data[data['diagnosis']=='B'][column], bins=30, alpha=0.5, color='blue', label='B')
    axs[i].set_title(column)
    axs[i].legend(loc='upper right')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [31], in <cell line: 5>()
#       3 axs = axs.ravel()
#       5 for i, column in enumerate(data.columns[2:]):
# ----> 6     axs[i].hist(data[data['diagnosis']=='M'][column], bins=30, alpha=0.5, color='red', label='M')
#       7     axs[i].hist(data[data['diagnosis']=='B'][column], bins=30, alpha=0.5, color='blue', label='B')
#       8     axs[i].set_title(column)
#
# IndexError: index 15 is out of bounds for axis 0 with size 15

# %%
sns.countplot(x="diagnosis", data=data)
plt.title("Nombre de patients par diagnostic")
plt.xlabel("Diagnostic")
plt.ylabel("Nombre de patients")
plt.show()

# %%
num_cols = data.columns[1:]
for col in num_cols:
    sns.histplot(data=data, x=col, hue="diagnosis", element="bars", kde=True)
    plt.title(f"Histogramme de {col}")
    plt.xlabel(col)
    plt.show()

# %%
plt.figure(figsize=(20,20))
corr = data.corr()
sns.heatmap(corr,cmap = "Blues",annot=True)
# Out:
# <AxesSubplot:>

# %%
q1 = data.quantile(0.25)
q3 = data.quantile(0.75)
iqr = q3 - q1
df = data[~((data < (q1 - 1.5 * iqr)) | (data > (q3 + 1.5 * iqr))).any(axis=1)]
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14784\816082341.py:4: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df = data[~((data < (q1 - 1.5 * iqr)) | (data > (q3 + 1.5 * iqr))).any(axis=1)]
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 6           M        18.25         19.98          119.60     1040.0
# 7           M        13.71         20.83           90.20      577.9
# 10          M        16.02         23.24          102.70      797.8
# 11          M        15.78         17.89          103.60      781.0
# 13          M        15.85         23.95          103.70      782.7
# ..        ...          ...           ...             ...        ...
# 554         B        12.88         28.92           82.50      514.3
# ...

# %%
df.shape
# Out:
# (398, 31)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df.iloc[:, 1:] = scaler.fit_transform(df.iloc[:, 1:])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14784\2062453499.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[:, 1:] = scaler.fit_transform(df.iloc[:, 1:])

# %%
df
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 6           M     1.964461      0.377377        1.973596   2.108920
# 7           M     0.134540      0.594978        0.225722   0.033027
# 10          M     1.065623      1.211941        0.968866   1.020884
# 11          M     0.968887     -0.157666        1.022372   0.945414
# 13          M     0.997102      1.393701        1.028317   0.953051
# ..        ...          ...           ...             ...        ...
# 554         B    -0.200005      2.666028       -0.232055  -0.252683
# 555         B    -1.243947      2.330666       -1.232624  -1.119248
# 558         B     0.489238      1.068580        0.593727   0.388818
# 560         B     0.271583      2.212905        0.295874   0.134104
# 566         M     1.299402      2.450986        1.301794   1.291770
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:, 1:], df.iloc[:, 0], test_size=0.2, random_state=42)

# %%
from sklearn.feature_selection import RFE
from sklearn.svm import SVC
estimator = SVC(kernel='linear')
selector = RFE(estimator, n_features_to_select=10, step=1)
selector = selector.fit(X_train, y_train)

# %%
selected_features = df.columns[1:][selector.support_]
print("Selected features:", selected_features)
# Out:
# Selected features: Index(['area_se', 'compactness_se', 'concavity_se', 'fractal_dimension_se',
#        'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst',
#        'concave points_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
svm_model = SVC(kernel='linear', C=1, gamma='auto')
svm_model.fit(X_train[selected_features], y_train)
# Out:
# SVC(C=1, gamma='auto', kernel='linear')

# %%
from sklearn.metrics import classification_report, confusion_matrix
y_pred = svm_model.predict(X_test[selected_features])
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[53  2]
#  [ 3 22]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            B       0.95      0.96      0.95        55
#            M       0.92      0.88      0.90        25
#
#     accuracy                           0.94        80
#    macro avg       0.93      0.92      0.93        80
# weighted avg       0.94      0.94      0.94        80
